# %% [markdown]
# 1.A retail company wants to reward its most valuable customers. Display the
# top 5 highest-value orders along with customer names
#   - "customername"	"orderid"	"orderamount"
# "Vikram Patel"	5011	42000.00
# "Rahul Sharma"	5009	30000.00
# "Priya Mehta"	5014	27000.00
# "Amit Verma"	5007	25000.00
# "Rahul Sharma"	5003	22000.00
#
# 2.The marketing team wants to send promotional emails to customers whose
# names start with 'A', 'R', or 'S'.
# Write a query without using multiple OR conditions.
#  - "customerid"	"customername"	"city"	"joindate"
# 101	"Rahul Sharma"	"Bangalore"	"2023-01-15"
# 103	"Arjun Nair"	"Chennai"	"2025-01-12"
# 104	"Sneha Gupta"	"Delhi"	"2022-07-10"
# 106	"Amit Verma"	"Pune"	"2023-11-05"
# 107	"Rohan Singh"	"Kolkata"	"2024-05-18"
# 108	"Simran Kaur"	"Delhi"	"2025-02-01"
# 109	"Anjali Jain"	"Mumbai"	"2023-09-22"
#
# 3.Management wants to identify customers who have placed orders worth
# more than ₹10,000 but whose order status is still Pending.
# Display:
# ● Customer Name
# ● Order ID
# ● Order Amount
# ● Status
#  - "customername"	"orderid"	"orderamount"	"status"
# "Rohan Singh"	5015	15500.00	"Pending"
#
# 4.The customer success team wants to identify customers who joined more
# than 365 days ago.
# Display the number of days each customer has been associated with the
# company.
#  - "customerid"	"customername"	"joindate"	"daysassociated"
# 101	"Rahul Sharma"	"2023-01-15"	1311
# 102	"Priya Mehta"	"2024-03-20"	881
# 103	"Arjun Nair"	"2025-01-12"	583
# 104	"Sneha Gupta"	"2022-07-10"	1500
# 105	"Kavya Reddy"	"2024-08-15"	733
# 106	"Amit Verma"	"2023-11-05"	1017
# 107	"Rohan Singh"	"2024-05-18"	822
# 108	"Simran Kaur"	"2025-02-01"	563
# 109	"Anjali Jain"	"2023-09-22"	1061
# 110	"Vikram Patel"	"2022-12-30"	1327
#
# 5.The finance department wants to estimate future revenue.
# Create a report showing:
# ● Order ID
# ● Current Amount
# ● 18% GST
# ● Total Amount After GST
# ● Expected Collection Date (15 days after order date)
#  - "orderid"	"currentamount"	"gst"	"totalamountaftergst"	"expectedcollectiondate"
# 5001	12000.00	2160.0000	14160.0000	"2025-01-20 00:00:00"
# 5002	8500.00	1530.0000	10030.0000	"2025-01-30 00:00:00"
# 5003	22000.00	3960.0000	25960.0000	"2025-02-25 00:00:00"
# 5004	4500.00	810.0000	5310.0000	"2025-03-02 00:00:00"
# 5005	17500.00	3150.0000	20650.0000	"2025-03-16 00:00:00"
# 5006	9800.00	1764.0000	11564.0000	"2025-03-25 00:00:00"
# 5007	25000.00	4500.0000	29500.0000	"2025-04-02 00:00:00"
# 5008	14500.00	2610.0000	17110.0000	"2025-04-17 00:00:00"
# 5009	30000.00	5400.0000	35400.0000	"2025-04-25 00:00:00"
# 5010	6500.00	1170.0000	7670.0000	"2025-04-30 00:00:00"
# 5011	42000.00	7560.0000	49560.0000	"2025-05-16 00:00:00"
# 5012	18000.00	3240.0000	21240.0000	"2025-05-23 00:00:00"
# 5013	7000.00	1260.0000	8260.0000	"2025-05-30 00:00:00"
# 5014	27000.00	4860.0000	31860.0000	"2025-06-04 00:00:00"
# 5015	15500.00	2790.0000	18290.0000	"2025-06-16 00:00:00"
#
# 6.The operations team wants to review the customers ranked between 11th and
# 20th highest orders.
# Use LIMIT and OFFSET.
#  - "customername"	"orderid"	"orderamount"
# "Kavya Reddy"	5006	9800.00
# "Priya Mehta"	5002	8500.00
# "Amit Verma"	5013	7000.00
# "Anjali Jain"	5010	6500.00
# "Sneha Gupta"	5004	4500.00
#
# 7.An e-commerce company wants to identify customers who have never
# placed any order despite registering on the platform.
# Display:
# ● Customer ID
# ● Customer Name
# ● Join Date
# ● Number of Days Since Registration
#  - "customerid"	"customername"	"joindate"	"dayssinceregistration"
# 108	"Simran Kaur"	"2025-02-01"	563
#
# 8.The HR department wants to analyze organizational hierarchy.
# Using a JOIN, display:
# ● Employee Name
# ● Manager Name
# ● Department
#  - "employeename"	"managername"	"department"
# "Neha Sharma"	"Rajesh Kumar"	"Sales"
# "Amit Gupta"	"Rajesh Kumar"	"IT"
# "Priyanka Singh"	"Neha Sharma"	"Sales"
# "Vikas Patel"	"Neha Sharma"	"Sales"
# "Rohit Jain"	"Amit Gupta"	"IT"
# "Anjali Verma"	"Amit Gupta"	"IT"
# "Karan Mehta"	"Rajesh Kumar"	"HR"
# "Sneha Kapoor"	"Karan Mehta"	"HR"
# "Arjun Malhotra"	"Amit Gupta"	"IT"
#
# 9.The sales director wants a report of customers who placed orders within 30
# days of joining the platform.
# Display:
# ● Customer Name
# ● Join Date
# ● Order Date
# ● Days Taken To Place First Order
#  - No result
#
# 10.Business Requirement
# Generate a report showing:
# ● Customer Name
# ● Total Purchase Amount
# ● Spending Category
# ● Loyalty Status
# Rules
# Spending Category
# ● Premium → Total Purchases > ₹50,000
# ● Gold → ₹20,000 to ₹50,000
# ● Silver → Less than ₹20,000
# Loyalty Status
# ● Joined before 2024 → Loyal Customer
# ● Otherwise → New Customer
#  - "customername"	"totalpurchaseamount"	"spendingcategory"	"loyaltystatus"
# "Rahul Sharma"	64000.00	"Premium"	"Loyal Customer"
# "Vikram Patel"	42000.00	"Gold"	"Loyal Customer"
# "Priya Mehta"	35500.00	"Gold"	"New Customer"
# "Amit Verma"	32000.00	"Gold"	"Loyal Customer"
# "Rohan Singh"	30000.00	"Gold"	"New Customer"
# "Sneha Gupta"	22500.00	"Gold"	"Loyal Customer"
# "Arjun Nair"	17500.00	"Silver"	"New Customer"
# "Kavya Reddy"	9800.00	"Silver"	"New Customer"
# "Anjali Jain"	6500.00	"Silver"	"Loyal Customer"
# "Simran Kaur"	0	"Silver"	"New Customer"
#
# 11.An online marketplace wants to find customers whose order
# amount is higher than the average order amount of all orders.
# Display:
# ● Customer Name
# ● Order ID
# ● Order Amount
#  - "customername"	"orderid"	"orderamount"
# "Vikram Patel"	5011	42000.00
# "Rahul Sharma"	5009	30000.00
# "Priya Mehta"	5014	27000.00
# "Amit Verma"	5007	25000.00
# "Rahul Sharma"	5003	22000.00
# "Sneha Gupta"	5012	18000.00
# "Arjun Nair"	5005	17500.00
#
# 12.The management team wants the 2nd to 6th highest orders placed by
# customers.
# Display:
# ● Customer Name
# ● Order ID
# ● Order Amount
#  - "customername"	"orderid"	"orderamount"
# "Rahul Sharma"	5009	30000.00
# "Priya Mehta"	5014	27000.00
# "Amit Verma"	5007	25000.00
# "Rahul Sharma"	5003	22000.00
# "Sneha Gupta"	5012	18000.00
#
# 13.
